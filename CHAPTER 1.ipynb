# %% [markdown]
# # Python Algorithmic Trading Cookbook

# %% [markdown]
# ## Chapter 1: Handling and Manipulating Date, Time and Time Series Data

# %% [markdown]
# This Jupyter Notebook is created using Python version 3.8.2

# %% [markdown]
# ----

# %% [markdown]
# ### Requirements

# %% [markdown]
# You can install the requirements for this Jupyter Notebook by executing the below cell

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting numpy>=1.22.4 (from pandas)
#   Downloading numpy-2.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from pandas) (2024.1)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /srv/conda/envs/notebook/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 32.6 MB/s eta 0:00:0000:0100:01
# Downloading numpy-2.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 30.5 MB/s eta 0:00:0000:0100:01
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 31.8 MB/s eta 0:00:00
# Installing collected packages: tzdata, numpy, pandas
# Successfully installed numpy-2.0.1 pandas-2.2.2 tzdata-2024.1

# %% [markdown]
# ----

# %% [markdown]
# ### Recipe 1:  Creating datetime objects

# %%
from datetime import datetime

# %%
dt1 = datetime.now()
print(f'Approach #1: {dt1}')
# Out:
# Approach #1: 2024-08-17 14:33:45.506693

# %%
print(f'Year: {dt1.year}')
print(f'Month: {dt1.month}')
print(f'Day: {dt1.day}')
print(f'Hours: {dt1.hour}')
print(f'Minutes: {dt1.minute}')
print(f'Seconds: {dt1.second}')
print(f'Microseconds: {dt1.microsecond}')
print(f'Timezone: {dt1.tzinfo}')
# Out:
# Year: 2024
# Month: 8
# Day: 17
# Hours: 14
# Minutes: 33
# Seconds: 45
# Microseconds: 506693
# Timezone: None

# %%
dt2 = datetime(year=2024, month=1, day=1)
print(f'Approach #2: {dt2}')
# Out:
# Approach #2: 2024-01-01 00:00:00

# %%
print(f'Year: {dt2.year}')
print(f'Month: {dt2.month}')
print(f'Day: {dt2.day}')
print(f'Hours: {dt2.hour}')
print(f'Minutes: {dt2.minute}')
print(f'Seconds: {dt2.second}')
print(f'Microseconds: {dt2.microsecond}')
print(f'Timezone: {dt2.tzinfo}')
# Out:
# Year: 2024
# Month: 1
# Day: 1
# Hours: 0
# Minutes: 0
# Seconds: 0
# Microseconds: 0
# Timezone: None

# %%
print(f"Date: {dt1.date()}")
print(f"Type: {type(dt1.date())}")
# Out:
# Date: 2024-08-17
# Type: <class 'datetime.date'>

# %%
print(f"Time: {dt1.time()}")
print(f"Type: {type(dt1.time())}")
# Out:
# Time: 14:33:45.506693
# Type: <class 'datetime.time'>

# %%
print(f"Date: {dt2.date()}")
print(f"Type: {type(dt2.date())}")
# Out:
# Date: 2024-01-01
# Type: <class 'datetime.date'>

# %%
print(f"Time: {dt2.time()}")
print(f"Type: {type(dt2.time())}")
# Out:
# Time: 00:00:00
# Type: <class 'datetime.time'>

# %% [markdown]
# ### Recipe 2: Creating timedetla objects

# %%
from datetime import timedelta

# %%
td1 = timedelta(days=5)
print(f'Time difference: {td1}')
# Out:
# Time difference: 5 days, 0:00:00

# %%
td2 = timedelta(days=4)
print(f'Time difference: {td2}')
# Out:
# Time difference: 4 days, 0:00:00

# %%
print(f'Addition: {td1} + {td2} = {td1 + td2}')
# Out:
# Addition: 5 days, 0:00:00 + 4 days, 0:00:00 = 9 days, 0:00:00

# %%
print(f'Subtraction: {td1} - {td2} = {td1 - td2}')
# Out:
# Subtraction: 5 days, 0:00:00 - 4 days, 0:00:00 = 1 day, 0:00:00

# %%
print(f'Multiplication: {td1} * 2.5 = {td1 * 2.5}')
# Out:
# Multiplication: 5 days, 0:00:00 * 2.5 = 12 days, 12:00:00

# %%
td3 = timedelta(hours=23, minutes=59, seconds=60)
print(f'Time difference: {td3}')
# Out:
# Time difference: 1 day, 0:00:00

# %%
print(f'Total seconds in 1 day: {td3.total_seconds()}')
# Out:
# Total seconds in 1 day: 86400.0

# %% [markdown]
# ### Recipe 3: Operations on datetime objects

# %%
from datetime import date, datetime, timedelta

# %%
date_today = date.today()
print(f"Today's Date: {date_today}")
# Out:
# Today's Date: 2024-08-17

# %%
date_5days_later = date_today + timedelta(days=5)
print(f"Date 5 days later: {date_5days_later}")
# Out:
# Date 5 days later: 2024-08-22

# %%
date_5days_ago = date_today - timedelta(days=5)
print(f"Date 5 days ago: {date_5days_ago}")
# Out:
# Date 5 days ago: 2024-08-12

# %%
date_5days_later > date_5days_ago
# Out:
# True

# %%
date_5days_later < date_5days_ago
# Out:
# False

# %%
date_5days_later > date_today > date_5days_ago
# Out:
# True

# %%
current_timestamp = datetime.now()

# %%
time_now = current_timestamp.time()
print(f"Time now: {time_now}")
# Out:
# Time now: 14:35:19.892007

# %%
time_5minutes_later = (current_timestamp + timedelta(minutes=5)).time()              # Note: operations are not allowed on time objects, so have to perform on datetime objects and then extract the time
print(f"Time 5 minutes later: {time_5minutes_later}")
# Out:
# Time 5 minutes later: 14:40:19.892007

# %%
time_5minutes_ago = (current_timestamp - timedelta(minutes=5)).time()              # Note: operations are not allowed on time objects, so have to perform on datetime objects and then extract the time
print(f"Time 5 minutes ago: {time_5minutes_ago}")
# Out:
# Time 5 minutes ago: 14:30:19.892007

# %%
time_5minutes_later < time_5minutes_ago
# Out:
# False

# %%
time_5minutes_later > time_5minutes_ago
# Out:
# True

# %%
time_5minutes_later > time_now > time_5minutes_ago
# Out:
# True

# %% [markdown]
# ### Recipe 4: Modifying datetime objects

# %%
from datetime import datetime

# %%
dt1 = datetime.now()
print(dt1)
# Out:
# 2024-08-17 14:35:44.751549

# %%
dt2 = dt1.replace(year=2021, month=1, day=1)
print(f'A timestamp from 1st January 2021: {dt2}')
# Out:
# A timestamp from 1st January 2021: 2021-01-01 14:35:44.751549

# %%
dt3 = datetime(year=2024, 
               month=1, 
               day=1, 
               hour=dt1.hour, 
               minute=dt1.minute, 
               second=dt1.second, 
               microsecond=dt1.microsecond, 
               tzinfo=dt1.tzinfo)
print(f'A timestamp from 1st January 2024: {dt3}')
# Out:
# A timestamp from 1st January 2024: 2024-01-01 14:35:44.751549

# %%
dt2 == dt3
# Out:
# False

# %% [markdown]
# ### Recipe 5: Converting a datetime object to a string

# %%
from datetime import datetime

# %%
now = datetime.now().astimezone()

# %%
print(str(now))
# Out:
# 2024-08-17 14:36:24.426196+00:00

# %%
print(now.strftime("%d-%m-%Y %H:%M:%S %z"))
# Out:
# 17-08-2024 14:36:24 +0000

# %% [markdown]
# ### Recipe 6: Creating a datetime object from a string

# %%
from datetime import datetime

# %%
now_str = '13-1-2024 15:53:39 +05:30'

# %%
now = datetime.strptime(now_str, "%d-%m-%Y %H:%M:%S %z")
print(now)
# Out:
# 2024-01-13 15:53:39+05:30

# %%
print(type(now))
# Out:
# <class 'datetime.datetime'>

# %% [markdown]
# ### There's more...

# %%
now = datetime.strptime(now_str, "%d-%m-%Y")
# Note: It's expected to get an error below
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 now = datetime.strptime(now_str, "%d-%m-%Y")
#       2 # Note: It's expected to get an error below
#
# File /srv/conda/envs/notebook/lib/python3.10/_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# File /srv/conda/envs/notebook/lib/python3.10/_strptime.py:352, in _strptime(data_string, format)
#     349     raise ValueError("time data %r does not match format %r" %
#     350                      (data_string, format))
#     351 if len(data_string) != found.end():
# --> 352     raise ValueError("unconverted data remains: %s" %
#     353                       data_string[found.end():])
#     355 iso_year = year = None
#     356 month = day = 1
#
# ValueError: unconverted data remains:  15:53:39 +05:30

# %% [markdown]
# ### Recipe 7: The datetime object and time zones

# %%
from datetime import datetime

# %%
now_tz_naive = datetime.now()                   # Timezone naive datetime object
print(now_tz_naive)
# Out:
# 2024-08-17 14:37:11.236870

# %%
print(now_tz_naive.tzinfo)
# Out:
# None

# %%
now_tz_aware = datetime.now().astimezone()      # Timezone aware datetime object
print(now_tz_aware)
# Out:
# 2024-08-17 14:37:17.343307+00:00

# %%
print(now_tz_aware.tzinfo)
# Out:
# UTC

# %%
new_tz_aware = now_tz_naive.replace(tzinfo=now_tz_aware.tzinfo)
print(new_tz_aware)
# Out:
# 2024-08-17 14:37:11.236870+00:00

# %%
print(new_tz_aware.tzinfo)
# Out:
# UTC

# %%
new_tz_naive = new_tz_aware.replace(tzinfo=None)
print(new_tz_naive)
# Out:
# 2024-08-17 14:37:11.236870

# %%
print(new_tz_naive.tzinfo)
# Out:
# None

# %%
new_tz_naive <= now_tz_naive
# Out:
# True

# %%
new_tz_aware <= now_tz_aware
# Out:
# True

# %%
new_tz_aware <= now_tz_naive
# Note: It's expected to get an error below
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 new_tz_aware <= now_tz_naive
#       2 # Note: It's expected to get an error below
#
# TypeError: can't compare offset-naive and offset-aware datetimes

# %% [markdown]
# ### Recipe 8: Creating a Pandas.Dataframe object

# %%
from datetime import datetime
import pandas

# %%
time_series_data = [
    {'date': datetime(2023, 11, 13, 9, 0),
     'open': 71.8075,
     'high': 71.845,
     'low': 71.7775,
     'close': 71.7925,
     'volume': 219512},
    {'date': datetime(2023, 11, 13, 9, 15),
     'open': 71.7925,
     'high': 71.8,
     'low': 71.78,
     'close': 71.7925,
     'volume': 59252},
    {'date': datetime(2023, 11, 13, 9, 30),
     'open': 71.7925,
     'high': 71.8125,
     'low': 71.76,
     'close': 71.7625,
     'volume': 57187},
    {'date': datetime(2023, 11, 13, 9, 45),
     'open': 71.76,
     'high': 71.765,
     'low': 71.735,
     'close': 71.7425,
     'volume': 43048},
    {'date': datetime(2023, 11, 13, 10, 0),
     'open': 71.7425,
     'high': 71.78,
     'low': 71.7425,
     'close': 71.7775,
     'volume': 45863},
    {'date': datetime(2023, 11, 13, 10, 15),
     'open': 71.775,
     'high': 71.8225,
     'low': 71.77,
     'close': 71.815,
     'volume': 42460},
    {'date': datetime(2023, 11, 13, 10, 30),
     'open': 71.815,
     'high': 71.83,
     'low': 71.7775,
     'close': 71.78,
     'volume': 62403},
    {'date': datetime(2023, 11, 13, 10, 45),
     'open': 71.775,
     'high': 71.7875,
     'low': 71.7475,
     'close': 71.7525,
     'volume': 34090},
    {'date': datetime(2023, 11, 13, 11, 0),
     'open': 71.7525,
     'high': 71.7825,
     'low': 71.7475,
     'close': 71.7625,
     'volume': 39320},
    {'date': datetime(2023, 11, 13, 11, 15),
     'open': 71.7625,
     'high': 71.7925,
     'low': 71.76,
     'close': 71.7875,
     'volume': 20190}
]

# %%
df = pandas.DataFrame(time_series_data)
df
# Out:
#                  date     open     high      low    close  volume
# 0 2023-11-13 09:00:00  71.8075  71.8450  71.7775  71.7925  219512
# 1 2023-11-13 09:15:00  71.7925  71.8000  71.7800  71.7925   59252
# 2 2023-11-13 09:30:00  71.7925  71.8125  71.7600  71.7625   57187
# 3 2023-11-13 09:45:00  71.7600  71.7650  71.7350  71.7425   43048
# 4 2023-11-13 10:00:00  71.7425  71.7800  71.7425  71.7775   45863
# 5 2023-11-13 10:15:00  71.7750  71.8225  71.7700  71.8150   42460
# 6 2023-11-13 10:30:00  71.8150  71.8300  71.7775  71.7800   62403
# 7 2023-11-13 10:45:00  71.7750  71.7875  71.7475  71.7525   34090
# 8 2023-11-13 11:00:00  71.7525  71.7825  71.7475  71.7625   39320
# 9 2023-11-13 11:15:00  71.7625  71.7925  71.7600  71.7875   20190

# %%
df.columns.tolist()
# Out:
# ['date', 'open', 'high', 'low', 'close', 'volume']

# %%
pandas.DataFrame(time_series_data, 
    columns=['close', 'date', 'open', 'high', 'low', 'volume'])
# Out:
#      close                date     open     high      low  volume
# 0  71.7925 2023-11-13 09:00:00  71.8075  71.8450  71.7775  219512
# 1  71.7925 2023-11-13 09:15:00  71.7925  71.8000  71.7800   59252
# 2  71.7625 2023-11-13 09:30:00  71.7925  71.8125  71.7600   57187
# 3  71.7425 2023-11-13 09:45:00  71.7600  71.7650  71.7350   43048
# 4  71.7775 2023-11-13 10:00:00  71.7425  71.7800  71.7425   45863
# 5  71.8150 2023-11-13 10:15:00  71.7750  71.8225  71.7700   42460
# 6  71.7800 2023-11-13 10:30:00  71.8150  71.8300  71.7775   62403
# 7  71.7525 2023-11-13 10:45:00  71.7750  71.7875  71.7475   34090
# 8  71.7625 2023-11-13 11:00:00  71.7525  71.7825  71.7475   39320
# 9  71.7875 2023-11-13 11:15:00  71.7625  71.7925  71.7600   20190

# %%
pandas.DataFrame(time_series_data, index=range(10, 20))
# Out:
# 8 2023-11-13 11:00:00  71.7525  71.7825  71.7475  71.7625   39320
# 7 2023-11-13 10:45:00  71.7750  71.7875  71.7475  71.7525   34090
# 6 2023-11-13 10:30:00  71.8150  71.8300  71.7775  71.7800   62403
# 5 2023-11-13 10:15:00  71.7750  71.8225  71.7700  71.8150   42460
# 4 2023-11-13 10:00:00  71.7425  71.7800  71.7425  71.7775   45863
# 3 2023-11-13 09:45:00  71.7600  71.7650  71.7350  71.7425   43048
# 2 2023-11-13 09:30:00  71.7925  71.8125  71.7600  71.7625   57187
# 1 2023-11-13 09:15:00  71.7925  71.8000  71.7800  71.7925   59252
# 0 2023-11-13 09:00:00  71.8075  71.8450  71.7775  71.7925  219512

# %%
df['close']
# Out:
# 0    71.7925
# 1    71.7925
# 2    71.7625
# 3    71.7425
# 4    71.7775
# 5    71.8150
# 6    71.7800
# 7    71.7525
# 8    71.7625
# 9    71.7875
# Name: close, dtype: float64

# %%
df.iloc[0]
# Out:
# timestamp    2023-11-13 09:00:00
# open                     71.8075
# high                      71.845
# low                      71.7775
# close                    71.7925
# volume                    219512
# Name: 0, dtype: object

# %%
df.iloc[:2, :2]
# Out:
#             timestamp     open
# 0 2023-11-13 09:00:00  71.8075
# 1 2023-11-13 09:15:00  71.7925

# %%
df.iloc[:, 4]
# Out:
# 0    71.7925
# 1    71.7925
# 2    71.7625
# 3    71.7425
# 4    71.7775
# 5    71.8150
# 6    71.7800
# 7    71.7525
# 8    71.7625
# 9    71.7875
# Name: close, dtype: float64

# %% [markdown]
# ### Recipes 10: Dataframe Manipulation: applying, sorting, iterating and concatenating

# %%
import pandas

# %%
df['timestamp'] = df['timestamp'].apply(
    lambda x: x.strftime("%d-%m-%Y %H:%M:%S"))
df
# Out:
#              timestamp     open     high      low    close  volume
# 0  13-11-2023 09:00:00  71.8075  71.8450  71.7775  71.7925  219512
# 1  13-11-2023 09:15:00  71.7925  71.8000  71.7800  71.7925   59252
# 2  13-11-2023 09:30:00  71.7925  71.8125  71.7600  71.7625   57187
# 3  13-11-2023 09:45:00  71.7600  71.7650  71.7350  71.7425   43048
# 4  13-11-2023 10:00:00  71.7425  71.7800  71.7425  71.7775   45863
# 5  13-11-2023 10:15:00  71.7750  71.8225  71.7700  71.8150   42460
# 6  13-11-2023 10:30:00  71.8150  71.8300  71.7775  71.7800   62403
# 7  13-11-2023 10:45:00  71.7750  71.7875  71.7475  71.7525   34090
# 8  13-11-2023 11:00:00  71.7525  71.7825  71.7475  71.7625   39320
# 9  13-11-2023 11:15:00  71.7625  71.7925  71.7600  71.7875   20190

# %%
df.sort_values(by='close', ascending=True)
# Out:
#              timestamp     open     high      low    close  volume
# 3  13-11-2023 09:45:00  71.7600  71.7650  71.7350  71.7425   43048
# 7  13-11-2023 10:45:00  71.7750  71.7875  71.7475  71.7525   34090
# 2  13-11-2023 09:30:00  71.7925  71.8125  71.7600  71.7625   57187
# 8  13-11-2023 11:00:00  71.7525  71.7825  71.7475  71.7625   39320
# 4  13-11-2023 10:00:00  71.7425  71.7800  71.7425  71.7775   45863
# 6  13-11-2023 10:30:00  71.8150  71.8300  71.7775  71.7800   62403
# 9  13-11-2023 11:15:00  71.7625  71.7925  71.7600  71.7875   20190
# 1  13-11-2023 09:15:00  71.7925  71.8000  71.7800  71.7925   59252
# 0  13-11-2023 09:00:00  71.8075  71.8450  71.7775  71.7925  219512
# 5  13-11-2023 10:15:00  71.7750  71.8225  71.7700  71.8150   42460

# %%
df.sort_values(by='open', ascending=False)
# Out:
#              timestamp     open     high      low    close  volume
# 6  13-11-2023 10:30:00  71.8150  71.8300  71.7775  71.7800   62403
# 0  13-11-2023 09:00:00  71.8075  71.8450  71.7775  71.7925  219512
# 1  13-11-2023 09:15:00  71.7925  71.8000  71.7800  71.7925   59252
# 2  13-11-2023 09:30:00  71.7925  71.8125  71.7600  71.7625   57187
# 7  13-11-2023 10:45:00  71.7750  71.7875  71.7475  71.7525   34090
# 5  13-11-2023 10:15:00  71.7750  71.8225  71.7700  71.8150   42460
# 9  13-11-2023 11:15:00  71.7625  71.7925  71.7600  71.7875   20190
# 3  13-11-2023 09:45:00  71.7600  71.7650  71.7350  71.7425   43048
# 8  13-11-2023 11:00:00  71.7525  71.7825  71.7475  71.7625   39320
# 4  13-11-2023 10:00:00  71.7425  71.7800  71.7425  71.7775   45863

# %%
for _, row in df.iterrows():
    avg = (row['open'] + row['close'] + row['high'] + row['low'])/4
    print(f"Index: {_} | Average: {avg}")
# Out:
# Index: 0 | Average: 71.805625
# Index: 1 | Average: 71.79124999999999
# Index: 2 | Average: 71.781875
# Index: 3 | Average: 71.750625
# Index: 4 | Average: 71.760625
# Index: 5 | Average: 71.795625
# Index: 6 | Average: 71.800625
# Index: 7 | Average: 71.765625
# Index: 8 | Average: 71.76124999999999
# Index: 9 | Average: 71.775625

# %%
for value in df.iloc[0]:
    print(value)
# Out:
# 13-11-2023 09:00:00
# 71.8075
# 71.845
# 71.7775
# 71.7925
# 219512

# %%
df_new = pandas.DataFrame([
    {'timestamp': datetime(2023, 11, 13, 11, 30),
     'open': 71.7875,
     'high': 71.8075,
     'low': 71.77,
     'close': 71.7925,
     'volume': 18655},
    {'timestamp': datetime(2023, 11, 13, 11, 45),
     'open': 71.7925,
     'high': 71.805,
     'low': 71.7625,
     'close': 71.7625,
     'volume': 25648},
    {'timestamp': datetime(2023, 11, 13, 12, 0),
     'open': 71.7625,
     'high': 71.805,
     'low': 71.75,
     'close': 71.785,
     'volume': 37300},
    {'timestamp': datetime(2023, 11, 13, 12, 15),
     'open': 71.785,
     'high': 71.7925,
     'low': 71.7575,
     'close': 71.7775,
     'volume': 15431},
    {'timestamp': datetime(2023, 11, 13, 12, 30),
     'open': 71.7775,
     'high': 71.795,
     'low': 71.7725,
     'close': 71.79,
     'volume': 5178}
])
df_new
# Out:
#             timestamp     open     high      low    close  volume
# 0 2023-11-13 11:30:00  71.7875  71.8075  71.7700  71.7925   18655
# 1 2023-11-13 11:45:00  71.7925  71.8050  71.7625  71.7625   25648
# 2 2023-11-13 12:00:00  71.7625  71.8050  71.7500  71.7850   37300
# 3 2023-11-13 12:15:00  71.7850  71.7925  71.7575  71.7775   15431
# 4 2023-11-13 12:30:00  71.7775  71.7950  71.7725  71.7900    5178

# %%
pandas.concat([df, df_new]).reset_index(drop=True)
# Out:
#               timestamp     open     high      low    close  volume
# 0   13-11-2023 09:00:00  71.8075  71.8450  71.7775  71.7925  219512
# 1   13-11-2023 09:15:00  71.7925  71.8000  71.7800  71.7925   59252
# 2   13-11-2023 09:30:00  71.7925  71.8125  71.7600  71.7625   57187
# 3   13-11-2023 09:45:00  71.7600  71.7650  71.7350  71.7425   43048
# 4   13-11-2023 10:00:00  71.7425  71.7800  71.7425  71.7775   45863
# 5   13-11-2023 10:15:00  71.7750  71.8225  71.7700  71.8150   42460
# 6   13-11-2023 10:30:00  71.8150  71.8300  71.7775  71.7800   62403
# 7   13-11-2023 10:45:00  71.7750  71.7875  71.7475  71.7525   34090
# 8   13-11-2023 11:00:00  71.7525  71.7825  71.7475  71.7625   39320
# 9   13-11-2023 11:15:00  71.7625  71.7925  71.7600  71.7875   20190
# 10  2023-11-13 11:30:00  71.7875  71.8075  71.7700  71.7925   18655
# 11  2023-11-13 11:45:00  71.7925  71.8050  71.7625  71.7625   25648
# 12  2023-11-13 12:00:00  71.7625  71.8050  71.7500  71.7850   37300
# 13  2023-11-13 12:15:00  71.7850  71.7925  71.7575  71.7775   15431
# 14  2023-11-13 12:30:00  71.7775  71.7950  71.7725  71.7900    5178

# %%
import random

# %%
df1 = pandas.DataFrame([random.randint(1,100) for i in range(10)], 
                       columns=['open'])
df1
# Out:
#    open
# 0    76
# 1    45
# 2    75
# 3    15
# 4    39
# 5    29
# 6    26
# 7    14
# 8    69
# 9    57

# %%
df2 = pandas.DataFrame([random.randint(1,100) for i in range(10)], 
                       columns=['close'])
df2
# Out:
#    close
# 0     44
# 1     78
# 2     41
# 3     98
# 4     23
# 5     66
# 6     30
# 7     23
# 8     75
# 9     19

# %%
pandas.concat([df1, df2], axis=1)
# Out:
#    open  close
# 0    76     44
# 1    45     78
# 2    75     41
# 3    15     98
# 4    39     23
# 5    29     66
# 6    26     30
# 7    14     23
# 8    69     75
# 9    57     19

# %% [markdown]
# ### Recipe 11: Converting a DataFrame into other formats

# %%
df.to_csv('dataframe.csv', index=False)

# %%
df.to_json()
# Out:
